# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
vi= int(input("cismin ilk hızını giriniz:"))
a= int(input("cismin ivmesini giriniz:"))
t=int(input(" geçen süreyi giriniz:"))
print("ilk hız=",vi,)
print("ivme=",a,)
print("zaman=",t,)

def sonHızBulma():
    return (vi+a*t)
sonHızBulma()
# Out:
# ilk hız= 4
# ivme= 3
# zaman= 2
# 10

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
def mukemmelSayi(x):
    toplam=0
    for i in range(1,x):
        if x%i==0:
            toplam+=i
    return x== toplam #bütün bölümler toplama eklendikten sonra denetlemesini istediğimiz için return for ile aynı hizada

for i in range(1,1000):
    if mukemmelSayi(i):
        print(i)
# Out:
# 6
# 28
# 496

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
def ucgen(max):
    ucgenler=[]
    for a in range(1,max):
        for b in range (1,max):
            c=(a**2+b**2)**0.5
            if c == int(c):
                ucgenler.append((a,b,c))
    return ucgenler

for i in ucgen(101):
    print(i)
# Out:
# (3, 4, 5.0)
# (4, 3, 5.0)
# (5, 12, 13.0)
# (6, 8, 10.0)
# (7, 24, 25.0)
# (8, 6, 10.0)
# (8, 15, 17.0)
# (9, 12, 15.0)
# (9, 40, 41.0)
# (10, 24, 26.0)
# (11, 60, 61.0)
# (12, 5, 13.0)
# (12, 9, 15.0)
# (12, 16, 20.0)
# (12, 35, 37.0)
# (13, 84, 85.0)
# (14, 48, 50.0)
# (15, 8, 17.0)
# (15, 20, 25.0)
# (15, 36, 39.0)
# (16, 12, 20.0)
# (16, 30, 34.0)
# (16, 63, 65.0)
# (18, 24, 30.0)
# (18, 80, 82.0)
# (20, 15, 25.0)
# (20, 21, 29.0)
# (20, 48, 52.0)
# (20, 99, 101.0)
# (21, 20, 29.0)
# (21, 28, 35.0)
# (21, 72, 75.0)
# (24, 7, 25.0)
# (24, 10, 26.0)
# (24, 18, 30.0)
# (24, 32, 40.0)
# (24, 45, 51.0)
# (24, 70, 74.0)
# (25, 60, 65.0)
# (27, 36, 45.0)
# (28, 21, 35.0)
# (28, 45, 53.0)
# (28, 96, 100.0)
# (30, 16, 34.0)
# (30, 40, 50.0)
# (30, 72, 78.0)
# (32, 24, 40.0)
# (32, 60, 68.0)
# (33, 44, 55.0)
# (33, 56, 65.0)
# (35, 12, 37.0)
# (35, 84, 91.0)
# (36, 15, 39.0)
# (36, 27, 45.0)
# (36, 48, 60.0)
# (36, 77, 85.0)
# (39, 52, 65.0)
# (39, 80, 89.0)
# (40, 9, 41.0)
# (40, 30, 50.0)
# (40, 42, 58.0)
# (40, 75, 85.0)
# (40, 96, 104.0)
# (42, 40, 58.0)
# (42, 56, 70.0)
# (44, 33, 55.0)
# (45, 24, 51.0)
# (45, 28, 53.0)
# (45, 60, 75.0)
# (48, 14, 50.0)
# (48, 20, 52.0)
# (48, 36, 60.0)
# (48, 55, 73.0)
# (48, 64, 80.0)
# (48, 90, 102.0)
# (51, 68, 85.0)
# (52, 39, 65.0)
# (54, 72, 90.0)
# (55, 48, 73.0)
# (56, 33, 65.0)
# (56, 42, 70.0)
# (56, 90, 106.0)
# (57, 76, 95.0)
# (60, 11, 61.0)
# (60, 25, 65.0)
# (60, 32, 68.0)
# (60, 45, 75.0)
# (60, 63, 87.0)
# (60, 80, 100.0)
# (60, 91, 109.0)
# (63, 16, 65.0)
# (63, 60, 87.0)
# (63, 84, 105.0)
# (64, 48, 80.0)
# (65, 72, 97.0)
# (66, 88, 110.0)
# (68, 51, 85.0)
# (69, 92, 115.0)
# (70, 24, 74.0)
# (72, 21, 75.0)
# (72, 30, 78.0)
# (72, 54, 90.0)
# (72, 65, 97.0)
# (72, 96, 120.0)
# (75, 40, 85.0)
# (75, 100, 125.0)
# (76, 57, 95.0)
# (77, 36, 85.0)
# (80, 18, 82.0)
# (80, 39, 89.0)
# (80, 60, 100.0)
# (80, 84, 116.0)
# (84, 13, 85.0)
# (84, 35, 91.0)
# (84, 63, 105.0)
# (84, 80, 116.0)
# (88, 66, 110.0)
# (90, 48, 102.0)
# (90, 56, 106.0)
# (91, 60, 109.0)
# (92, 69, 115.0)
# (96, 28, 100.0)
# (96, 40, 104.0)
# (96, 72, 120.0)
# (99, 20, 101.0)
# (100, 75, 125.0)

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
import math

duvarYuksekligi=int(input("Duvar yuksekligini giriniz:"))
duvarGenisligi=int(input("Duvar genisligini giriniz:"))
kutuBasinaKaplama=5

def kutuSayisi():
    return math.ceil((duvarYuksekligi*duvarGenisligi)/kutuBasinaKaplama)
    
kutuSayisi()
# Out:
# 2

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
kelime= input("Bir kelime giriniz:")
sesliHafler="A,a,E,e,I,ı,İ,i,O,o,Ö,ö,U,u,Ü,ü"
sessizHarfler="Z,z,Y,y,V,v,T,t,Ş,ş,S,s,R,r,P,p,N,n,R,r,M,m,L,l,K,k,H,h,J,j,ğ,G,g,D,d,Ç,ç,C,c,B,b"
sessizHarfSayaci=0
sesliHarfSayaci=0
for i in kelime:
    if i in sesliHafler:
        sesliHarfSayaci+=1
    else:
        sessizHarfSayaci+=1

print(kelime,"metnindeki sesli harf sayisi",sesliHarfSayaci, "sessiz harf sayisi ise", sessizHarfSayaci,)
# Out:
# Ayşe metnindeki sesli harf sayisi 2 sessiz harf sayisi ise 2

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
liste=[]
N=int(input("Girmek istediğiniz eleman sayisini giriniz:"))
for i in range(N):
    sayi=int(input("Bir sayi giriniz:"))
    liste.append(sayi)

def ciftSayilar(i):
    if i%2==0 or i==0:
        return (i ,"çift sayidir")
    else:
        return(i,"çift sayi değildir")
ciftSayilar(i)
# Out:
# (2, 'çift sayidir')

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
def toplam(x):
    if x!=0:
        return x + toplam(x-1)
    else:
        return 0
    

toplam(10)
# Out:
# 55
