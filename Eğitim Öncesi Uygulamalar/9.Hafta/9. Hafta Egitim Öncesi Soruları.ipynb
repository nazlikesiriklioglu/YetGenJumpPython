# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
# Vehicle sınıfı için hangi bilgiler lazım olduğunu anlamadığımdan direkt miras alınmış şekliyle yazdım.
class Bus(Vehicle):
    def seating_capacity(self, capacity=50):
        self.capacity = capacity
        print(f"The seating capacity of a bus is {self.capacity} passengers")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Vehicle sınıfı için hangi bilgiler lazım olduğunu anlamadığımdan direkt miras alınmış şekliyle yazdım.
# ----> 2 class Bus(Vehicle):
#       3     def seating_capacity(self, capacity=50):
#       4         self.capacity = capacity
#
# NameError: name 'Vehicle' is not defined

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
class Vehicle:
    pass

class School_bus(Vehicle):
    pass

my_school_bus = School_bus()
print(isinstance(my_school_bus, Vehicle))
# Out:
# True
